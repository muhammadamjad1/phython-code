# %%
numbers=[1,2,3,4,5,6,7,8]
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list = ["amjad", "arsam", "waqas", "wajid", "abid"]
a = [word for word in list if word.startswith("a")]
print(a)
# Out:
# ['amjad', 'arsam', 'abid']

# %%
my_list = ["wajid", "waheed", "amjad", "waqaswaqar", "arsam"]
a = [word for word in my_list if word.startswith("w")]
print(a)
# Out:
# ['wajid', 'waheed', 'waqaswaqar']

# %%
lst =[" i love pakistan ", "amjaid" ,"eisa"]
for a in range(100):
    print(a ,lst[0:4])
# Out:
# 0 [' i love pakistan ', 'amjaid', 'eisa']
# 1 [' i love pakistan ', 'amjaid', 'eisa']
# 2 [' i love pakistan ', 'amjaid', 'eisa']
# 3 [' i love pakistan ', 'amjaid', 'eisa']
# 4 [' i love pakistan ', 'amjaid', 'eisa']
# 5 [' i love pakistan ', 'amjaid', 'eisa']
# 6 [' i love pakistan ', 'amjaid', 'eisa']
# 7 [' i love pakistan ', 'amjaid', 'eisa']
# 8 [' i love pakistan ', 'amjaid', 'eisa']
# 9 [' i love pakistan ', 'amjaid', 'eisa']
# 10 [' i love pakistan ', 'amjaid', 'eisa']
# 11 [' i love pakistan ', 'amjaid', 'eisa']
# 12 [' i love pakistan ', 'amjaid', 'eisa']
# 13 [' i love pakistan ', 'amjaid', 'eisa']
# 14 [' i love pakistan ', 'amjaid', 'eisa']
# 15 [' i love pakistan ', 'amjaid', 'eisa']
# 16 [' i love pakistan ', 'amjaid', 'eisa']
# 17 [' i love pakistan ', 'amjaid', 'eisa']
# 18 [' i love pakistan ', 'amjaid', 'eisa']
# 19 [' i love pakistan ', 'amjaid', 'eisa']
# 20 [' i love pakistan ', 'amjaid', 'eisa']
# 21 [' i love pakistan ', 'amjaid', 'eisa']
# ...

# %%
lst =[" i love pakistan "]
for a in lst:
    print(a )
# Out:
#  i love pakistan

# %%
import time

lst = ["pakistan tahrek insaf"]

for a in range(100):
    print(a, lst[0:])
    time.sleep(1)  # Introducing a delay of 1 second (1000 milliseconds)
# Out:
# 0 ['pakistan tahrek insaf']
# 1 ['pakistan tahrek insaf']
# 2 ['pakistan tahrek insaf']
# 3 ['pakistan tahrek insaf']
# 4 ['pakistan tahrek insaf']
# 5 ['pakistan tahrek insaf']
# 6 ['pakistan tahrek insaf']
# 7 ['pakistan tahrek insaf']
# 8 ['pakistan tahrek insaf']
# 9 ['pakistan tahrek insaf']
# 10 ['pakistan tahrek insaf']
# 11 ['pakistan tahrek insaf']
# 12 ['pakistan tahrek insaf']
# 13 ['pakistan tahrek insaf']
# 14 ['pakistan tahrek insaf']
# 15 ['pakistan tahrek insaf']
# 16 ['pakistan tahrek insaf']
# 17 ['pakistan tahrek insaf']
# 18 ['pakistan tahrek insaf']
# 19 ['pakistan tahrek insaf']
# 20 ['pakistan tahrek insaf']
# 21 ['pakistan tahrek insaf']
# 22 ['pakistan tahrek insaf']
# 23 ['pakistan tahrek insaf']
# 24 ['pakistan tahrek insaf']
# 25 ['pakistan tahrek insaf']
# 26 ['pakistan tahrek insaf']
# 27 ['pakistan tahrek insaf']
# 28 ['pakistan tahrek insaf']
# 29 ['pakistan tahrek insaf']
# 30 ['pakistan tahrek insaf']
# 31 ['pakistan tahrek insaf']
# ...

# %%
lst =["pakistan tahrek insaf"]
for a in range(100):
    print(a ,lst[0:])
delay(1000)
# Out:
# 0 ['pakistan tahrek insaf']
# 1 ['pakistan tahrek insaf']
# 2 ['pakistan tahrek insaf']
# 3 ['pakistan tahrek insaf']
# 4 ['pakistan tahrek insaf']
# 5 ['pakistan tahrek insaf']
# 6 ['pakistan tahrek insaf']
# 7 ['pakistan tahrek insaf']
# 8 ['pakistan tahrek insaf']
# 9 ['pakistan tahrek insaf']
# 10 ['pakistan tahrek insaf']
# 11 ['pakistan tahrek insaf']
# 12 ['pakistan tahrek insaf']
# 13 ['pakistan tahrek insaf']
# 14 ['pakistan tahrek insaf']
# 15 ['pakistan tahrek insaf']
# 16 ['pakistan tahrek insaf']
# 17 ['pakistan tahrek insaf']
# 18 ['pakistan tahrek insaf']
# 19 ['pakistan tahrek insaf']
# 20 ['pakistan tahrek insaf']
# 21 ['pakistan tahrek insaf']
# 22 ['pakistan tahrek insaf']
# 23 ['pakistan tahrek insaf']
# 24 ['pakistan tahrek insaf']
# 25 ['pakistan tahrek insaf']
# 26 ['pakistan tahrek insaf']
# 27 ['pakistan tahrek insaf']
# 28 ['pakistan tahrek insaf']
# 29 ['pakistan tahrek insaf']
# 30 ['pakistan tahrek insaf']
# 31 ['pakistan tahrek insaf']
# ...

# %%
import time
lst =["arsam""mobile""shop"]
#delay the programe
for a in range(5):
    print(a ,lst[0:3])
    time.sleep(2)
    #time sleep is the print lst in 1 second (1000ms)
# Out:
# 0 ['arsammobileshop']
# 1 ['arsammobileshop']
# 2 ['arsammobileshop']
# 3 ['arsammobileshop']
# 4 ['arsammobileshop']
